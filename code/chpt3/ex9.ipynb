# %% [markdown]
# ## Description
#
# Let $X_1$, $X_2$, ... , $X_n$ be $N(0, 1)$ random variables, and let $\overline X_n = n^{-1} \sum _{i = 1}^n X_i$. Plot $\overline X_n$ versus $n$ for $n = 1, \dots, 10000$. Repeat for $X_1, X_2, ... , X_n \sim Cauchy$. Explain why there is such a difference.

# %%
using Pkg
Pkg.add("Plots")
Pkg.add("Distributions")

using Plots, Random, Distributions, Statistics
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
X_n = 1:10000 .|> n -> mean(rand(Normal(0, 1), n))
# Out:
# 10000-element Vector{Float64}:
#   1.0574392920475733
#   0.4781819798242194
#  -0.36969418206587434
#  -0.7990026233626363
#   0.38000621060198847
#  -0.05437877872490562
#  -0.22569682588232415
#  -0.13586152732178747
#  -0.17107366743082308
#   0.6464764435842174
#   ⋮
#   0.0014023425389077632
#  -0.00742446348950165
#  -0.008374827131143597
#  -0.009215630388162562
#   0.013234543243035917
#  -0.003252423188757713
#   0.0018935103734386807
#   0.005597553506224034
#   0.008179053286629523

# %%
plot(1:10000, X_n)

# %%
Y_n = X_n = 1:10000 .|> n -> mean(rand(Cauchy(), n))
# Out:
# 10000-element Vector{Float64}:
#  -1.8003834975329474
#  -2.263956549058831
#   0.0831787963542207
#   9.002424742842777
#  -0.3738644926950746
#  10.108652381259724
#  12.803891056487714
#  -3.5490556310611567
#  -0.15459052975520274
#   0.3883611412025707
#   ⋮
#  -2.5101842792316433
#  -0.7026502630456253
#   0.8081119538642334
#   1.3073101179250461
#  -3.7526442571912066
#   0.3962528600595783
#  -3.3370899185617455
#   2.619665156124915
#   0.33267446702908454

# %%
plot(1:10000, Y_n)

# %% [markdown]
# The main difference of the plots results from their variance.
